# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
import urllib

import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.datasets import mnist
from tensorflow import keras
AUTOTUNE = tf.data.experimental.AUTOTUNE

import tensorflow_docs as tfdocs
from tensorflow_docs import plots

import PIL.Image

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = (12,5)

# %%
image_path = keras.utils.get_file('cat.jpg', "https://storage.googleapis.com/download.tensorflow.org/example_images/320px-Felis_catus-cat_on_snow.jpg")
PIL.Image.open(image_path)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/320px-Felis_catus-cat_on_snow.jpg
# 24576/17858 [=========================================] - 0s 0us/step
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213 at 0x7F2136F036D8>

# %%
image_string = tf.io.read_file(image_path)
image = tf.image.decode_jpeg(image_string, channels=3)

# %%
def visualize(original, augmented):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Original Image')
    plt.imshow(image)

    plt.subplot(1,2,2)
    plt.title('Augemented Image')
    plt.imshow(augmented)

# %% [markdown]
# ### Flipping

# %%
flipped = tf.image.flip_left_right(image)
visualize(image, flipped)

# %% [markdown]
# ### Grayscaling

# %%
grayscaled = tf.image.rgb_to_grayscale(image)
visualize(image, tf.squeeze(grayscaled))
plt.colorbar()

# %% [markdown]
# ### Saturate

# %%
saturated = tf.image.adjust_saturation(image, 4)
visualize(image, saturated)

# %% [markdown]
# ### Brighten

# %%
brightened = tf.image.adjust_brightness(image, 0.3)
visualize(image, brightened)

# %% [markdown]
# ### Rotate

# %%
rotated = tf.image.rot90(image)
visualize(image, rotated)

# %% [markdown]
# ### Center Crop

# %%
cropped = tf.image.central_crop(image, 0.5)
visualize(image, cropped)

# %% [markdown]
# ## Model Training and Comparisons

# %%
dataset, info = tfds.load('mnist', as_supervised=True, with_info=True)
train_dataset, test_dataset = dataset['train'], dataset['test']

num_train_examples = info.splits['train'].num_examples

# %%
def convert(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image, label

def augment(image, label):
    image, label = convert(image, label)
    image = tf.image.resize_with_crop_or_pad(image, 34, 34)
    image = tf.image.random_crop(image, size=[28,28,1])
    image = tf.image.random_brightness(image, max_delta=0.5)
    return image, label

# %%
BATCH_SIZE = 64
NUM_EXAMPLES = 2048

# %%
augmented_train_batches = (
    train_dataset
    .take(NUM_EXAMPLES).cache()
    .shuffle(num_train_examples//4)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

non_augmented_train_batch = (
    train_dataset
    .take(NUM_EXAMPLES).cache()
    .shuffle(num_train_examples//4)
    .map(convert, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# %%
validation_batches = (
    test_dataset
    .map(convert, num_parallel_calls=AUTOTUNE)
    .batch(2*BATCH_SIZE)
)

# %%
def make_model():
    model = keras.Sequential([
                              keras.layers.Flatten(input_shape=(28,28,1)),
                              keras.layers.Dense(4096, activation='relu'),
                              keras.layers.Dense(4096, activation='relu'),
                              keras.layers.Dense(10)
    ])
    model.compile(optimizer='adam', loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
    return model

# %%
model_without_aug = make_model()

no_aug_history = model_without_aug.fit(non_augmented_train_batch, epochs=50, validation_data=validation_batches)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.8353 - accuracy: 0.7637 - val_loss: 0.3469 - val_accuracy: 0.8984
# Epoch 2/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1514 - accuracy: 0.9507 - val_loss: 0.3242 - val_accuracy: 0.9128
# Epoch 3/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0849 - accuracy: 0.9731 - val_loss: 0.3118 - val_accuracy: 0.9179
# Epoch 4/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0382 - accuracy: 0.9858 - val_loss: 0.3304 - val_accuracy: 0.9238
# Epoch 5/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0280 - accuracy: 0.9917 - val_loss: 0.3121 - val_accuracy: 0.9285
# Epoch 6/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.3844 - val_accuracy: 0.9198
# Epoch 7/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 0.4686 - val_accuracy: 0.9112
# Epoch 8/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0311 - accuracy: 0.9907 - val_loss: 0.4313 - val_accuracy: 0.9159
# Epoch 9/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0344 - accuracy: 0.9888 - val_loss: 0.3941 - val_accuracy: 0.9238
# Epoch 10/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0443 - accuracy: 0.9834 - val_loss: 0.4390 - val_accuracy: 0.9189
# Epoch 11/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0539 - accuracy: 0.9849 - val_loss: 0.5308 - val_accuracy: 0.9024
# Epoch 12/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0641 - accuracy: 0.9775 - val_loss: 0.4500 - val_accuracy: 0.9164
# Epoch 13/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0303 - accuracy: 0.9922 - val_loss: 0.4024 - val_accuracy: 0.9239
# Epoch 14/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0277 - accuracy: 0.9922 - val_loss: 0.3753 - val_accuracy: 0.9310
# Epoch 15/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0303 - accuracy: 0.9927 - val_loss: 0.4415 - val_accuracy: 0.9244
# Epoch 16/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0302 - accuracy: 0.9922 - val_loss: 0.4120 - val_accuracy: 0.9247
# Epoch 17/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.3852 - val_accuracy: 0.9325
# Epoch 18/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3679 - val_accuracy: 0.9377
# Epoch 19/50
# 32/32 [==============================] - 2s 63ms/step - loss: 2.3478e-04 - accuracy: 1.0000 - val_loss: 0.3699 - val_accuracy: 0.9376
# Epoch 20/50
# 32/32 [==============================] - 2s 63ms/step - loss: 8.7890e-05 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 0.9385
# Epoch 21/50
# Epoch 42/50
# 32/32 [==============================] - 2s 63ms/step - loss: 2.3942e-06 - accuracy: 1.0000 - val_loss: 0.4829 - val_accuracy: 0.9399
# Epoch 43/50
# 32/32 [==============================] - 2s 64ms/step - loss: 2.2303e-06 - accuracy: 1.0000 - val_loss: 0.4866 - val_accuracy: 0.9396
# Epoch 44/50
# 32/32 [==============================] - 2s 65ms/step - loss: 2.0814e-06 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.9398
# Epoch 45/50
# 32/32 [==============================] - 2s 64ms/step - loss: 1.9416e-06 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9395
# Epoch 46/50
# 32/32 [==============================] - 2s 64ms/step - loss: 1.8367e-06 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 0.9398
# Epoch 47/50
# 32/32 [==============================] - 2s 65ms/step - loss: 1.7639e-06 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.9399
# Epoch 48/50
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6869e-06 - accuracy: 1.0000 - val_loss: 0.4984 - val_accuracy: 0.9397
# Epoch 49/50
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6224e-06 - accuracy: 1.0000 - val_loss: 0.5012 - val_accuracy: 0.9396
# Epoch 50/50
# 32/32 [==============================] - 2s 63ms/step - loss: 1.5382e-06 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.9397

# %%
model_with_aug = make_model()

aug_history = model_with_aug.fit(augmented_train_batches, epochs=50, validation_data=validation_batches)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 2s 65ms/step - loss: 2.2755 - accuracy: 0.3115 - val_loss: 1.1915 - val_accuracy: 0.7019
# Epoch 2/50
# 32/32 [==============================] - 2s 64ms/step - loss: 1.2728 - accuracy: 0.5767 - val_loss: 0.7002 - val_accuracy: 0.7956
# Epoch 3/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.9248 - accuracy: 0.6924 - val_loss: 0.4468 - val_accuracy: 0.8725
# Epoch 4/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.7633 - accuracy: 0.7417 - val_loss: 0.4729 - val_accuracy: 0.8500
# Epoch 5/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.6507 - accuracy: 0.7764 - val_loss: 0.3748 - val_accuracy: 0.8815
# Epoch 6/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.6387 - accuracy: 0.7896 - val_loss: 0.3531 - val_accuracy: 0.8873
# Epoch 7/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.4779 - accuracy: 0.8472 - val_loss: 0.3037 - val_accuracy: 0.9042
# Epoch 8/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.4662 - accuracy: 0.8433 - val_loss: 0.2874 - val_accuracy: 0.9083
# Epoch 9/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.4719 - accuracy: 0.8564 - val_loss: 0.2686 - val_accuracy: 0.9168
# Epoch 10/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.3789 - accuracy: 0.8745 - val_loss: 0.2354 - val_accuracy: 0.9230
# Epoch 11/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2380 - accuracy: 0.9243 - val_loss: 0.1733 - val_accuracy: 0.9477
# Epoch 33/50
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1970 - accuracy: 0.9302 - val_loss: 0.1700 - val_accuracy: 0.9456
# Epoch 34/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2364 - accuracy: 0.9209 - val_loss: 0.1875 - val_accuracy: 0.9428
# Epoch 35/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2043 - accuracy: 0.9316 - val_loss: 0.1642 - val_accuracy: 0.9486
# Epoch 36/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2185 - accuracy: 0.9341 - val_loss: 0.1536 - val_accuracy: 0.9537
# Epoch 37/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.2169 - accuracy: 0.9268 - val_loss: 0.1536 - val_accuracy: 0.9538
# Epoch 38/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.2006 - accuracy: 0.9385 - val_loss: 0.1604 - val_accuracy: 0.9511
# Epoch 39/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1980 - accuracy: 0.9365 - val_loss: 0.1590 - val_accuracy: 0.9518
# Epoch 40/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1897 - accuracy: 0.9341 - val_loss: 0.1390 - val_accuracy: 0.9568
# Epoch 41/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1614 - accuracy: 0.9429 - val_loss: 0.1440 - val_accuracy: 0.9551
# Epoch 42/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1955 - accuracy: 0.9380 - val_loss: 0.1621 - val_accuracy: 0.9524
# Epoch 43/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1788 - accuracy: 0.9443 - val_loss: 0.1634 - val_accuracy: 0.9513
# Epoch 44/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1705 - accuracy: 0.9424 - val_loss: 0.1431 - val_accuracy: 0.9576
# Epoch 45/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1371 - accuracy: 0.9551 - val_loss: 0.1425 - val_accuracy: 0.9554
# Epoch 46/50
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1638 - accuracy: 0.9438 - val_loss: 0.1530 - val_accuracy: 0.9547
# Epoch 47/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1273 - accuracy: 0.9575 - val_loss: 0.1441 - val_accuracy: 0.9574
# Epoch 48/50
# 32/32 [==============================] - 2s 65ms/step - loss: 0.1483 - accuracy: 0.9521 - val_loss: 0.1746 - val_accuracy: 0.9492
# Epoch 49/50
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1734 - accuracy: 0.9419 - val_loss: 0.1814 - val_accuracy: 0.9496
# Epoch 50/50
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1400 - accuracy: 0.9468 - val_loss: 0.1617 - val_accuracy: 0.9524

# %%
plotter = tfdocs.plots.HistoryPlotter()
plotter.plot({'Augmented': aug_history, 'Non Augmented': no_aug_history}, metric='accuracy')
plt.title('Accuracy')
plt.ylim([0.75,1])
# Out:
# (0.75, 1.0)

# %%
plotter.plot({'Augmented': aug_history, 'Non Augmented': no_aug_history}, metric='loss')
plt.title('Loss')
plt.ylim([0,1])
# Out:
# (0.0, 1.0)
